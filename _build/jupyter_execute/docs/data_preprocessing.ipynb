# %% [markdown]
# # Data Preprocessing

# %%
# Import packages
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

# %% [markdown]
# Github: https://github.com/anetey-abbey/infoviz.git <br>
# Notebook: https://anetey-abbey.github.io/infoviz/docs/notebook.html

# %% [markdown]
# ## Load data
#
# Import the country dataset to get the codes of the countries in the WDI dataset in order to differentiate from groups of countries, e.g. Europe.

# %%
# this dataset contains the meta data of the WDI dataset
df_countrydata = pd.read_csv('WDICountry.csv', sep=',')

# %% [markdown]
# Import the WDI dataset and selected relevant indicators.

# %%
df = pd.read_csv('WDIData.csv', sep=',') 
df = df.drop('Unnamed: 66', axis=1)

# filter on period 1990 - 2020
years = list(map(str, range(1990, 2021)))
df = df[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'] + years]

# filter to keep only relevant variables in dataset
selected_indicators = ['GDP growth (annual %)',
                       'Individuals using the Internet (% of population)',
                       'Foreign direct investment, net inflows (BoP, current US$)',
                       'GNI per capita, PPP (current international $)',
                       'School enrollment, secondary (% net)',
                       'Individuals using the Internet (% of population)',
                        "Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)",
                       'Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)',
                       "Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)",
                       'Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)',
                       'Government expenditure on education, total (% of GDP)',
                       'Secondary education, duration (years)',
                       'Secondary education, pupils',
                       'Adjusted savings: education expenditure (% of GNI)',
                       'Adjusted savings: education expenditure (current US$)',
                       'Compulsory education, duration (years)',
                       'Secure Internet servers',
                       'Fixed telephone subscriptions',
                       'Access to electricity (% of population)',
                       'ICT goods exports (% of total goods exports)',
                       'Mobile cellular subscriptions',
                       'Mobile cellular subscriptions (per 100 people)',
                       'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)',
                       'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)',
                       'School enrollment, tertiary (% gross)',
                       'School enrollment, secondary (% gross)',
                       'School enrollment, primary (% gross)',
                       'Literacy rate, youth total (% of people ages 15-24)',
                       'Literacy rate, adult total (% of people ages 15 and above)', 
                       'ICT goods imports (% total goods imports)']
df = df[df['Indicator Name'].isin(selected_indicators)]

# Print the head
df.head(2)
# Out:
#                    Country Name Country Code  \
# 3   Africa Eastern and Southern          AFE
# 36  Africa Eastern and Southern          AFE
#
#                                        Indicator Name     Indicator Code  \
# 3             Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 36  Adjusted savings: education expenditure (% of ...  NY.ADJ.AEDU.GN.ZS
#
#         1990      1991      1992      1993     1994      1995  ...       2011  \
# 3        NaN       NaN       NaN       NaN      NaN       NaN  ...  29.089827
# 36  4.426717  4.882468  6.162041  6.071125  6.04343  6.990009  ...   4.755062
#
#          2012       2013       2014       2015       2016       2017  \
# 3   31.844384  31.794160  32.001027  33.871910  38.880173  40.261358
# 36   4.878013   4.563364   4.510963   4.433471   4.355900   4.442274
#
#          2018       2019       2020
# 3   43.061877  44.270860  45.803485
# 36   4.692845   4.791304   4.710650
#
# [2 rows x 35 columns]

# %% [markdown]
# For effective data analysis we need the data in the wide format but with the variable names in the columns.

# %%
df_long = df.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                  var_name='Year', value_name='Value')

df_wide = df_long.pivot_table(index=['Year', 'Country Name', 'Country Code'], 
                              columns='Indicator Name', values='Value', aggfunc='first')

df_wide = df_wide.reset_index()
df_wide['Year'] = df_wide['Year'].astype(int)

df_wide
# Out:
# Indicator Name  Year                 Country Name Country Code  \
# 0               1990                  Afghanistan          AFG
# 1               1990  Africa Eastern and Southern          AFE
# 2               1990   Africa Western and Central          AFW
# 3               1990                      Albania          ALB
# 4               1990                      Algeria          DZA
# ...              ...                          ...          ...
# 8206            2020           West Bank and Gaza          PSE
# 8207            2020                        World          WLD
# 8208            2020                  Yemen, Rep.          YEM
# 8209            2020                       Zambia          ZMB
# 8210            2020                     Zimbabwe          ZWE
#
# Indicator Name  Access to electricity (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                            100.000000
# 4                                                   NaN
# ...                                                 ...
# 8206                                         100.000000
# 8207                                          90.521569
# 8208                                          73.757927
# 8209                                          44.524475
# 8210                                          52.747669
#
# Indicator Name  Adjusted savings: education expenditure (% of GNI)  \
# 0                                                        1.953448
# 1                                                        4.426717
# 2                                                        2.615379
# 3                                                        2.800000
# 4                                                        4.946261
# ...                                                           ...
# 8206                                                          NaN
# 8207                                                     3.872891
# 8208                                                     3.600000
# 8209                                                     3.563864
# 8210                                                     1.910000
#
# Indicator Name  Adjusted savings: education expenditure (current US$)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                    5.674630e+07
# 4                                                    2.957000e+09
# ...                                                           ...
# 8206                                                          NaN
# 8207                                                          NaN
# 8208                                                          NaN
# 8209                                                 6.273000e+08
# 8210                                                 3.333000e+08
#
# Indicator Name  Compulsory education, duration (years)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8206                                              10.0
# 8207                                              10.0
# 8208                                               9.0
# 8209                                               7.0
# 8210                                               7.0
#
# Indicator Name  Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 8206                                                      0.26999
# 8207                                                          NaN
# 8208                                                          NaN
# 8209                                                          NaN
# 8210                                                          NaN
#
# Indicator Name  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 8206                                                    21.708691
# 8207                                                          NaN
# 8208                                                          NaN
# 8209                                                          NaN
# 8210                                                          NaN
#
# Indicator Name  Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 8206                                                      1.94667
# 8207                                                          NaN
# 8208                                                          NaN
# 8209                                                          NaN
# 8210                                                          NaN
#
# Indicator Name  ...  Literacy rate, youth total (% of people ages 15-24)  \
# 0               ...                                                NaN
# 1               ...                                                NaN
# 2               ...                                                NaN
# 3               ...                                                NaN
# 4               ...                                                NaN
# ...             ...                                                ...
# 8206            ...                                          99.232353
# 8207            ...                                          91.883980
# 8208            ...                                                NaN
# 8209            ...                                                NaN
# 8210            ...                                                NaN
#
# Indicator Name  Mobile cellular subscriptions  \
# 0                                0.000000e+00
# 1                                7.880000e+03
# 2                                0.000000e+00
# 3                                0.000000e+00
# 4                                4.700000e+02
# ...                                       ...
# 8206                             4.274119e+06
# 8207                             8.265682e+09
# 8208                             1.517800e+07
# 8209                             1.910421e+07
# 8210                             1.319171e+07
#
# Indicator Name  Mobile cellular subscriptions (per 100 people)  \
# 0                                                     0.000000
# 1                                                     0.002587
# 2                                                     0.000000
# 3                                                     0.000000
# 4                                                     0.001825
# ...                                                        ...
# 8206                                                 83.783026
# 8207                                                106.152775
# 8208                                                 50.888548
# 8209                                                103.917835
# 8210                                                 88.755806
#
# Indicator Name  School enrollment, primary (% gross)  \
# 0                                          29.041420
# 1                                                NaN
# 2                                                NaN
# 3                                          99.451752
# 4                                          92.593437
# ...                                              ...
# 8206                                       96.427193
# 8207                                      102.407066
# 8208                                             NaN
# 8209                                             NaN
# 8210                                       97.304909
#
# Indicator Name  School enrollment, secondary (% gross)  \
# 0                                            10.849960
# 1                                                  NaN
# 2                                                  NaN
# 3                                            90.081741
# 4                                            59.414188
# ...                                                ...
# 8206                                         91.027290
# 8207                                         76.750740
# 8208                                               NaN
# 8209                                               NaN
# 8210                                               NaN
#
# Indicator Name  School enrollment, secondary (% net)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8206                                             NaN
# 8207                                             NaN
# 8208                                             NaN
# 8209                                             NaN
# 8210                                             NaN
#
# Indicator Name  School enrollment, tertiary (% gross)  \
# 0                                            2.211410
# 1                                                 NaN
# 2                                                 NaN
# 3                                            8.366360
# 4                                           10.293140
# ...                                               ...
# 8206                                        43.097672
# 8207                                        40.244061
# 8208                                              NaN
# 8209                                              NaN
# 8210                                              NaN
#
# Indicator Name  Secondary education, duration (years)  \
# 0                                                 6.0
# 1                                                 6.0
# 2                                                 7.0
# 3                                                 8.0
# 4                                                 6.0
# ...                                               ...
# 8206                                              8.0
# 8207                                              6.0
# 8208                                              6.0
# 8209                                              5.0
# 8210                                              6.0
#
# Indicator Name  Secondary education, pupils  Secure Internet servers
# 0                                  182340.0                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                  475074.0                      NaN
# 4                                 2162469.0                      NaN
# ...                                     ...                      ...
# 8206                               806276.0                   2573.0
# 8207                            613156032.0               89189073.0
# 8208                                    NaN                    169.0
# 8209                                    NaN                    745.0
# 8210                                    NaN                   1107.0
#
# [8211 rows x 32 columns]

# %%
# join the continent data to the dataset
df_wide = pd.merge(df_wide, df_countrydata[['Country Code', 'Region']], on='Country Code', how='left')
df_wide
# Out:
#       Year                 Country Name Country Code  \
# 0     1990                  Afghanistan          AFG
# 1     1990  Africa Eastern and Southern          AFE
# 2     1990   Africa Western and Central          AFW
# 3     1990                      Albania          ALB
# 4     1990                      Algeria          DZA
# ...    ...                          ...          ...
# 8206  2020           West Bank and Gaza          PSE
# 8207  2020                        World          WLD
# 8208  2020                  Yemen, Rep.          YEM
# 8209  2020                       Zambia          ZMB
# 8210  2020                     Zimbabwe          ZWE
#
#       Access to electricity (% of population)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  100.000000
# 4                                         NaN
# ...                                       ...
# 8206                               100.000000
# 8207                                90.521569
# 8208                                73.757927
# 8209                                44.524475
# 8210                                52.747669
#
#       Adjusted savings: education expenditure (% of GNI)  \
# 0                                              1.953448
# 1                                              4.426717
# 2                                              2.615379
# 3                                              2.800000
# 4                                              4.946261
# ...                                                 ...
# 8206                                                NaN
# 8207                                           3.872891
# 8208                                           3.600000
# 8209                                           3.563864
# 8210                                           1.910000
#
#       Adjusted savings: education expenditure (current US$)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                          5.674630e+07
# 4                                          2.957000e+09
# ...                                                 ...
# 8206                                                NaN
# 8207                                                NaN
# 8208                                                NaN
# 8209                                       6.273000e+08
# 8210                                       3.333000e+08
#
#       Compulsory education, duration (years)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 8206                                    10.0
# 8207                                    10.0
# 8208                                     9.0
# 8209                                     7.0
# 8210                                     7.0
#
#       Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8206                                            0.26999
# 8207                                                NaN
# 8208                                                NaN
# 8209                                                NaN
# 8210                                                NaN
#
#       Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8206                                          21.708691
# 8207                                                NaN
# 8208                                                NaN
# 8209                                                NaN
# 8210                                                NaN
#
#       Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8206                                            1.94667
# 8207                                                NaN
# 8208                                                NaN
# 8209                                                NaN
# 8210                                                NaN
#
#       ...  Mobile cellular subscriptions  \
# 0     ...                   0.000000e+00
# 1     ...                   7.880000e+03
# 2     ...                   0.000000e+00
# 3     ...                   0.000000e+00
# 4     ...                   4.700000e+02
# ...   ...                            ...
# 8206  ...                   4.274119e+06
# 8207  ...                   8.265682e+09
# 8208  ...                   1.517800e+07
# 8209  ...                   1.910421e+07
# 8210  ...                   1.319171e+07
#
#       Mobile cellular subscriptions (per 100 people)  \
# 0                                           0.000000
# 1                                           0.002587
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.001825
# ...                                              ...
# 8206                                       83.783026
# 8207                                      106.152775
# 8208                                       50.888548
# 8209                                      103.917835
# 8210                                       88.755806
#
#       School enrollment, primary (% gross)  \
# 0                                29.041420
# 1                                      NaN
# 2                                      NaN
# 3                                99.451752
# 4                                92.593437
# ...                                    ...
# 8206                             96.427193
# 8207                            102.407066
# 8208                                   NaN
# 8209                                   NaN
# 8210                             97.304909
#
#       School enrollment, secondary (% gross)  \
# 0                                  10.849960
# 1                                        NaN
# 2                                        NaN
# 3                                  90.081741
# 4                                  59.414188
# ...                                      ...
# 8206                               91.027290
# 8207                               76.750740
# 8208                                     NaN
# 8209                                     NaN
# 8210                                     NaN
#
#       School enrollment, secondary (% net)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8206                                   NaN
# 8207                                   NaN
# 8208                                   NaN
# 8209                                   NaN
# 8210                                   NaN
#
#       School enrollment, tertiary (% gross)  \
# 0                                  2.211410
# 1                                       NaN
# 2                                       NaN
# 3                                  8.366360
# 4                                 10.293140
# ...                                     ...
# 8206                              43.097672
# 8207                              40.244061
# 8208                                    NaN
# 8209                                    NaN
# 8210                                    NaN
#
#       Secondary education, duration (years)  Secondary education, pupils  \
# 0                                       6.0                     182340.0
# 1                                       6.0                          NaN
# 2                                       7.0                          NaN
# 3                                       8.0                     475074.0
# 4                                       6.0                    2162469.0
# ...                                     ...                          ...
# 8206                                    8.0                     806276.0
# 8207                                    6.0                  613156032.0
# 8208                                    6.0                          NaN
# 8209                                    5.0                          NaN
# 8210                                    6.0                          NaN
#
#       Secure Internet servers                      Region
# 0                         NaN                  South Asia
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN       Europe & Central Asia
# 4                         NaN  Middle East & North Africa
# ...                       ...                         ...
# 8206                   2573.0  Middle East & North Africa
# 8207               89189073.0                         NaN
# 8208                    169.0  Middle East & North Africa
# 8209                    745.0          Sub-Saharan Africa
# 8210                   1107.0          Sub-Saharan Africa
#
# [8211 rows x 33 columns]

# %%
# most of the time we need the data of all countries only thus we filter out all non-country data
df_countrydata = df_countrydata[df_countrydata['Income Group'].notna()]
country_codes = df_countrydata['Country Code'].unique()
df_all_countries = df_wide[df_wide['Country Code'].isin(country_codes)]

# %%
# Replace 'nan' with np.nan
df_all_countries.replace('nan', np.nan, inplace=True)

# Convert columns to numeric data type
df_all_countries['Individuals using the Internet (% of population)'] = pd.to_numeric(df_all_countries['Individuals using the Internet (% of population)'], errors='coerce')

# Replace missing values with linearly interpolated values
df_all_countries = df_all_countries.interpolate(method='linear')
# Out:
# /var/folders/v9/_3m9v4153zx32g3v3h3vvfp00000gn/T/ipykernel_40171/1657942527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_countries.replace('nan', np.nan, inplace=True)
# /var/folders/v9/_3m9v4153zx32g3v3h3vvfp00000gn/T/ipykernel_40171/1657942527.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_countries['Individuals using the Internet (% of population)'] = pd.to_numeric(df_all_countries['Individuals using the Internet (% of population)'], errors='coerce')

# %%
# Save as pickle file. This datatype preserves all relevant information of the dataframe.
df_wide.to_pickle("df_wide.pkl")
df_all_countries.to_pickle("df_all_countries.pkl")

# %%
# Replace 'nan' with np.nan
df_all_countries.replace('nan', np.nan, inplace=True)

# Convert columns to numeric data type
df_all_countries['School enrollment, tertiary (% gross)'] = pd.to_numeric(df_all_countries['School enrollment, tertiary (% gross)'], errors='coerce')
df_all_countries['School enrollment, secondary (% gross)'] = pd.to_numeric(df_all_countries['School enrollment, secondary (% gross)'], errors='coerce')

# Replace missing values with linearly interpolated values
df_all_countries_clean = df_all_countries.interpolate(method='linear')

# %%
# Save as pickle file. This datatype preserves all relevant information of the dataframe.
df_all_countries_clean.to_pickle("df_all_countries_clean.pkl")
